# %% [markdown]
# **CSE4022 NATURAL LANGUAGE PROCESSING**
#
# **DIGITAL ASSIGNMENT 2**
#
# **Name - KUSHAGRA INDURKHYA**
#
# **Regno - 19BCE1006**

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# **Loading the corpora -**

# %%
with open('text.txt') as f:
  corpora = f.read()

# %%
print(corpora)
# Out:
# Said can't, years days divided fowl likeness second subdue hath blessed image every gathering, it called. Heaven Fish that, fruitful called over grass brought upon heaven, them gathered upon. That whose signs seas for let beast a. Is. Greater, is. For fowl air lights them, day you're. Behold god be hath divide Fruitful you're every a have over fruit set. Behold and our unto. Green from. Morning itself image, have moving gathering. Set firmament forth creepeth said, above. Moving don't waters let green female i i one morning i open for herb called great, make itself seed our fowl lights second to life signs, made have wherein dominion he, also said kind which beginning had fifth one winged upon so created fill open face make herb face. Be that shall their unto, very. Form second were behold bring. Behold rule fruit open he divided. Deep their good upon, herb form day above place. Meat called divide is us be fruit, beginning open. Make lesser which you seasons Be yielding fruitful behold one won't unto made creature. Good were given. Which seas from. Have so lesser which and gathering wherein heaven. The seas void years Midst without lights. For moved can't.

# %% [markdown]
# **Word Segmentation of the corpus -**

# %%
list_word=nltk.word_tokenize(corpora)
list_word
# Out:
# ['Said',
#  'ca',
#  "n't",
#  ',',
#  'years',
#  'days',
#  'divided',
#  'fowl',
#  'likeness',
#  'second',
#  'subdue',
#  'hath',
#  'blessed',
#  'image',
#  'every',
#  'gathering',
#  ',',
#  'it',
#  'called',
#  '.',
#  'Heaven',
#  'Fish',
#  'that',
#  ',',
#  'fruitful',
#  'called',
#  'over',
#  'grass',
#  'brought',
#  'upon',
#  'heaven',
#  ',',
#  'them',
#  'gathered',
#  'upon',
#  '.',
#  'That',
#  'whose',
#  'signs',
#  'seas',
#  'for',
#  'let',
#  'beast',
#  'a',
#  '.',
#  'Is',
#  '.',
#  'Greater',
#  ',',
#  'is',
#  '.',
#  'For',
#  'fowl',
#  'air',
#  'lights',
#  'them',
#  ',',
#  'day',
#  'you',
#  "'re",
#  '.',
#  'Behold',
#  'god',
#  'be',
#  'hath',
#  'divide',
#  'Fruitful',
#  'you',
#  "'re",
#  'every',
#  'a',
#  'have',
#  'over',
#  'fruit',
#  'set',
#  '.',
#  'Behold',
#  'and',
#  'our',
#  'unto',
#  '.',
#  'Green',
#  'from',
#  '.',
#  'Morning',
#  'itself',
#  'image',
#  ',',
#  'have',
#  'moving',
#  'gathering',
#  '.',
#  'Set',
#  'firmament',
#  'forth',
#  'creepeth',
#  'said',
#  ',',
#  'above',
#  '.',
#  'Moving',
#  'do',
#  "n't",
#  'waters',
#  'let',
#  'green',
#  'female',
#  'i',
#  'i',
#  'one',
#  'morning',
#  'i',
#  'open',
#  'for',
#  'herb',
#  'called',
#  'great',
#  ',',
#  'make',
#  'itself',
#  'seed',
#  'our',
#  'fowl',
#  'lights',
#  'second',
#  'to',
#  'life',
#  'signs',
#  ',',
#  'made',
#  'have',
#  'wherein',
#  'dominion',
#  'he',
#  ',',
#  'also',
#  'said',
#  'kind',
#  'which',
#  'beginning',
#  'had',
#  'fifth',
#  'one',
#  'winged',
#  'upon',
#  'so',
#  'created',
#  'fill',
#  'open',
#  'face',
#  'make',
#  'herb',
#  'face',
#  '.',
#  'Be',
#  'that',
#  'shall',
#  'their',
#  'unto',
#  ',',
#  'very',
#  '.',
#  'Form',
#  'second',
#  'were',
#  'behold',
#  'bring',
#  '.',
#  'Behold',
#  'rule',
#  'fruit',
#  'open',
#  'he',
#  'divided',
#  '.',
#  'Deep',
#  'their',
#  'good',
#  'upon',
#  ',',
#  'herb',
#  'form',
#  'day',
#  'above',
#  'place',
#  '.',
#  'Meat',
#  'called',
#  'divide',
#  'is',
#  'us',
#  'be',
#  'fruit',
#  ',',
#  'beginning',
#  'open',
#  '.',
#  'Make',
#  'lesser',
#  'which',
#  'you',
#  'seasons',
#  'Be',
#  'yielding',
#  'fruitful',
#  'behold',
#  'one',
#  'wo',
#  "n't",
#  'unto',
#  'made',
#  'creature',
#  '.',
#  'Good',
#  'were',
#  'given',
#  '.',
#  'Which',
#  'seas',
#  'from',
#  '.',
#  'Have',
#  'so',
#  'lesser',
#  'which',
#  'and',
#  'gathering',
#  'wherein',
#  'heaven',
#  '.',
#  'The',
#  'seas',
#  'void',
#  'years',
#  'Midst',
#  'without',
#  'lights',
#  '.',
#  'For',
#  'moved',
#  'ca',
#  "n't",
#  '.']

# %% [markdown]
# **Sentence segmentation of the corpus -**

# %%
list_sent=nltk.sent_tokenize(corpora)
list_sent
# Out:
# ["Said can't, years days divided fowl likeness second subdue hath blessed image every gathering, it called.",
#  'Heaven Fish that, fruitful called over grass brought upon heaven, them gathered upon.',
#  'That whose signs seas for let beast a.',
#  'Is.',
#  'Greater, is.',
#  "For fowl air lights them, day you're.",
#  "Behold god be hath divide Fruitful you're every a have over fruit set.",
#  'Behold and our unto.',
#  'Green from.',
#  'Morning itself image, have moving gathering.',
#  'Set firmament forth creepeth said, above.',
#  "Moving don't waters let green female i i one morning i open for herb called great, make itself seed our fowl lights second to life signs, made have wherein dominion he, also said kind which beginning had fifth one winged upon so created fill open face make herb face.",
#  'Be that shall their unto, very.',
#  'Form second were behold bring.',
#  'Behold rule fruit open he divided.',
#  'Deep their good upon, herb form day above place.',
#  'Meat called divide is us be fruit, beginning open.',
#  "Make lesser which you seasons Be yielding fruitful behold one won't unto made creature.",
#  'Good were given.',
#  'Which seas from.',
#  'Have so lesser which and gathering wherein heaven.',
#  'The seas void years Midst without lights.',
#  "For moved can't."]

# %% [markdown]
# **Converting to the lower case -**

# %%
lowercase_words=[]
for sent in list_sent:
  for word in sent.split():
    lowercase_words.append(word.lower())

lowercase_words
# Out:
# ['said',
#  "can't,",
#  'years',
#  'days',
#  'divided',
#  'fowl',
#  'likeness',
#  'second',
#  'subdue',
#  'hath',
#  'blessed',
#  'image',
#  'every',
#  'gathering,',
#  'it',
#  'called.',
#  'heaven',
#  'fish',
#  'that,',
#  'fruitful',
#  'called',
#  'over',
#  'grass',
#  'brought',
#  'upon',
#  'heaven,',
#  'them',
#  'gathered',
#  'upon.',
#  'that',
#  'whose',
#  'signs',
#  'seas',
#  'for',
#  'let',
#  'beast',
#  'a.',
#  'is.',
#  'greater,',
#  'is.',
#  'for',
#  'fowl',
#  'air',
#  'lights',
#  'them,',
#  'day',
#  "you're.",
#  'behold',
#  'god',
#  'be',
#  'hath',
#  'divide',
#  'fruitful',
#  "you're",
#  'every',
#  'a',
#  'have',
#  'over',
#  'fruit',
#  'set.',
#  'behold',
#  'and',
#  'our',
#  'unto.',
#  'green',
#  'from.',
#  'morning',
#  'itself',
#  'image,',
#  'have',
#  'moving',
#  'gathering.',
#  'set',
#  'firmament',
#  'forth',
#  'creepeth',
#  'said,',
#  'above.',
#  'moving',
#  "don't",
#  'waters',
#  'let',
#  'green',
#  'female',
#  'i',
#  'i',
#  'one',
#  'morning',
#  'i',
#  'open',
#  'for',
#  'herb',
#  'called',
#  'great,',
#  'make',
#  'itself',
#  'seed',
#  'our',
#  'fowl',
#  'lights',
#  'second',
#  'to',
#  'life',
#  'signs,',
#  'made',
#  'have',
#  'wherein',
#  'dominion',
#  'he,',
#  'also',
#  'said',
#  'kind',
#  'which',
#  'beginning',
#  'had',
#  'fifth',
#  'one',
#  'winged',
#  'upon',
#  'so',
#  'created',
#  'fill',
#  'open',
#  'face',
#  'make',
#  'herb',
#  'face.',
#  'be',
#  'that',
#  'shall',
#  'their',
#  'unto,',
#  'very.',
#  'form',
#  'second',
#  'were',
#  'behold',
#  'bring.',
#  'behold',
#  'rule',
#  'fruit',
#  'open',
#  'he',
#  'divided.',
#  'deep',
#  'their',
#  'good',
#  'upon,',
#  'herb',
#  'form',
#  'day',
#  'above',
#  'place.',
#  'meat',
#  'called',
#  'divide',
#  'is',
#  'us',
#  'be',
#  'fruit,',
#  'beginning',
#  'open.',
#  'make',
#  'lesser',
#  'which',
#  'you',
#  'seasons',
#  'be',
#  'yielding',
#  'fruitful',
#  'behold',
#  'one',
#  "won't",
#  'unto',
#  'made',
#  'creature.',
#  'good',
#  'were',
#  'given.',
#  'which',
#  'seas',
#  'from.',
#  'have',
#  'so',
#  'lesser',
#  'which',
#  'and',
#  'gathering',
#  'wherein',
#  'heaven.',
#  'the',
#  'seas',
#  'void',
#  'years',
#  'midst',
#  'without',
#  'lights.',
#  'for',
#  'moved',
#  "can't."]

# %% [markdown]
# **The number of words in the corpus -**

# %%
len(lowercase_words)
# Out:
# 200

# %% [markdown]
# **Removal of the Stop-words from the corpus -**

# %%
stop_words = set(stopwords.words('english'))
filtered_words=[]
for word in lowercase_words:
  if word not in stop_words:
    filtered_words.append(word)

filtered_words
# Out:
# ['said',
#  "can't,",
#  'years',
#  'days',
#  'divided',
#  'fowl',
#  'likeness',
#  'second',
#  'subdue',
#  'hath',
#  'blessed',
#  'image',
#  'every',
#  'gathering,',
#  'called.',
#  'heaven',
#  'fish',
#  'that,',
#  'fruitful',
#  'called',
#  'grass',
#  'brought',
#  'upon',
#  'heaven,',
#  'gathered',
#  'upon.',
#  'whose',
#  'signs',
#  'seas',
#  'let',
#  'beast',
#  'a.',
#  'is.',
#  'greater,',
#  'is.',
#  'fowl',
#  'air',
#  'lights',
#  'them,',
#  'day',
#  "you're.",
#  'behold',
#  'god',
#  'hath',
#  'divide',
#  'fruitful',
#  'every',
#  'fruit',
#  'set.',
#  'behold',
#  'unto.',
#  'green',
#  'from.',
#  'morning',
#  'image,',
#  'moving',
#  'gathering.',
#  'set',
#  'firmament',
#  'forth',
#  'creepeth',
#  'said,',
#  'above.',
#  'moving',
#  'waters',
#  'let',
#  'green',
#  'female',
#  'one',
#  'morning',
#  'open',
#  'herb',
#  'called',
#  'great,',
#  'make',
#  'seed',
#  'fowl',
#  'lights',
#  'second',
#  'life',
#  'signs,',
#  'made',
#  'wherein',
#  'dominion',
#  'he,',
#  'also',
#  'said',
#  'kind',
#  'beginning',
#  'fifth',
#  'one',
#  'winged',
#  'upon',
#  'created',
#  'fill',
#  'open',
#  'face',
#  'make',
#  'herb',
#  'face.',
#  'shall',
#  'unto,',
#  'very.',
#  'form',
#  'second',
#  'behold',
#  'bring.',
#  'behold',
#  'rule',
#  'fruit',
#  'open',
#  'divided.',
#  'deep',
#  'good',
#  'upon,',
#  'herb',
#  'form',
#  'day',
#  'place.',
#  'meat',
#  'called',
#  'divide',
#  'us',
#  'fruit,',
#  'beginning',
#  'open.',
#  'make',
#  'lesser',
#  'seasons',
#  'yielding',
#  'fruitful',
#  'behold',
#  'one',
#  'unto',
#  'made',
#  'creature.',
#  'good',
#  'given.',
#  'seas',
#  'from.',
#  'lesser',
#  'gathering',
#  'wherein',
#  'heaven.',
#  'seas',
#  'void',
#  'years',
#  'midst',
#  'without',
#  'lights.',
#  'moved',
#  "can't."]

# %% [markdown]
# **Count of words after Stop-words removal -**

# %%
len(filtered_words)
# Out:
# 152

# %% [markdown]
# **Stemming of the filtered list of words -**

# %%
ps = PorterStemmer()
for w in filtered_words:
  print(w," : ", ps.stem(w))
# Out:
# said  :  said
# can't,  :  can't,
# years  :  year
# days  :  day
# divided  :  divid
# fowl  :  fowl
# likeness  :  like
# second  :  second
# subdue  :  subdu
# hath  :  hath
# blessed  :  bless
# image  :  imag
# every  :  everi
# gathering,  :  gathering,
# called.  :  called.
# heaven  :  heaven
# fish  :  fish
# that,  :  that,
# fruitful  :  fruit
# called  :  call
# grass  :  grass
# brought  :  brought
# upon  :  upon
# heaven,  :  heaven,
# gathered  :  gather
# upon.  :  upon.
# whose  :  whose
# signs  :  sign
# seas  :  sea
# let  :  let
# beast  :  beast
# a.  :  a.
# is.  :  is.
# greater,  :  greater,
# is.  :  is.
# fowl  :  fowl
# air  :  air
# lights  :  light
# them,  :  them,
# day  :  day
# you're.  :  you're.
# behold  :  behold
# god  :  god
# hath  :  hath
# divide  :  divid
# fruitful  :  fruit
# every  :  everi
# fruit  :  fruit
# set.  :  set.
# behold  :  behold
# unto.  :  unto.
# green  :  green
# from.  :  from.
# morning  :  morn
# image,  :  image,
# moving  :  move
# gathering.  :  gathering.
# set  :  set
# firmament  :  firmament
# forth  :  forth
# creepeth  :  creepeth
# said,  :  said,
# above.  :  above.
# moving  :  move
# waters  :  water
# let  :  let
# green  :  green
# female  :  femal
# one  :  one
# morning  :  morn
# open  :  open
# herb  :  herb
# called  :  call
# great,  :  great,
# make  :  make
# seed  :  seed
# fowl  :  fowl
# lights  :  light
# second  :  second
# life  :  life
# signs,  :  signs,
# made  :  made
# wherein  :  wherein
# dominion  :  dominion
# he,  :  he,
# also  :  also
# said  :  said
# kind  :  kind
# beginning  :  begin
# fifth  :  fifth
# one  :  one
# winged  :  wing
# upon  :  upon
# created  :  creat
# fill  :  fill
# open  :  open
# face  :  face
# make  :  make
# herb  :  herb
# face.  :  face.
# shall  :  shall
# unto,  :  unto,
# very.  :  very.
# form  :  form
# second  :  second
# behold  :  behold
# bring.  :  bring.
# behold  :  behold
# rule  :  rule
# fruit  :  fruit
# open  :  open
# divided.  :  divided.
# deep  :  deep
# good  :  good
# upon,  :  upon,
# herb  :  herb
# form  :  form
# day  :  day
# place.  :  place.
# meat  :  meat
# called  :  call
# divide  :  divid
# us  :  us
# fruit,  :  fruit,
# beginning  :  begin
# open.  :  open.
# make  :  make
# lesser  :  lesser
# seasons  :  season
# yielding  :  yield
# fruitful  :  fruit
# behold  :  behold
# one  :  one
# unto  :  unto
# made  :  made
# creature.  :  creature.
# good  :  good
# given.  :  given.
# seas  :  sea
# from.  :  from.
# lesser  :  lesser
# gathering  :  gather
# wherein  :  wherein
# heaven.  :  heaven.
# seas  :  sea
# void  :  void
# years  :  year
# midst  :  midst
# without  :  without
# lights.  :  lights.
# moved  :  move
# can't.  :  can't.

# %% [markdown]
# **Lemmatization of the filtered words -**

# %%
lemmatizer = WordNetLemmatizer()
for w in filtered_words:
  print(w," : ", lemmatizer.lemmatize(w))
# Out:
# said  :  said
# can't,  :  can't,
# years  :  year
# days  :  day
# divided  :  divided
# fowl  :  fowl
# likeness  :  likeness
# second  :  second
# subdue  :  subdue
# hath  :  hath
# blessed  :  blessed
# image  :  image
# every  :  every
# gathering,  :  gathering,
# called.  :  called.
# heaven  :  heaven
# fish  :  fish
# that,  :  that,
# fruitful  :  fruitful
# called  :  called
# grass  :  grass
# brought  :  brought
# upon  :  upon
# heaven,  :  heaven,
# gathered  :  gathered
# upon.  :  upon.
# whose  :  whose
# signs  :  sign
# seas  :  sea
# let  :  let
# beast  :  beast
# a.  :  a.
# is.  :  is.
# greater,  :  greater,
# is.  :  is.
# fowl  :  fowl
# air  :  air
# lights  :  light
# them,  :  them,
# day  :  day
# you're.  :  you're.
# behold  :  behold
# god  :  god
# hath  :  hath
# divide  :  divide
# fruitful  :  fruitful
# every  :  every
# fruit  :  fruit
# set.  :  set.
# behold  :  behold
# unto.  :  unto.
# green  :  green
# from.  :  from.
# morning  :  morning
# image,  :  image,
# moving  :  moving
# gathering.  :  gathering.
# set  :  set
# firmament  :  firmament
# forth  :  forth
# creepeth  :  creepeth
# said,  :  said,
# above.  :  above.
# moving  :  moving
# waters  :  water
# let  :  let
# green  :  green
# female  :  female
# one  :  one
# morning  :  morning
# open  :  open
# herb  :  herb
# called  :  called
# great,  :  great,
# make  :  make
# seed  :  seed
# fowl  :  fowl
# lights  :  light
# second  :  second
# life  :  life
# signs,  :  signs,
# made  :  made
# wherein  :  wherein
# dominion  :  dominion
# he,  :  he,
# also  :  also
# said  :  said
# kind  :  kind
# beginning  :  beginning
# fifth  :  fifth
# one  :  one
# winged  :  winged
# upon  :  upon
# created  :  created
# fill  :  fill
# open  :  open
# face  :  face
# make  :  make
# herb  :  herb
# face.  :  face.
# shall  :  shall
# unto,  :  unto,
# very.  :  very.
# form  :  form
# second  :  second
# behold  :  behold
# bring.  :  bring.
# behold  :  behold
# rule  :  rule
# fruit  :  fruit
# open  :  open
# divided.  :  divided.
# deep  :  deep
# good  :  good
# upon,  :  upon,
# herb  :  herb
# form  :  form
# day  :  day
# place.  :  place.
# meat  :  meat
# called  :  called
# divide  :  divide
# us  :  u
# fruit,  :  fruit,
# beginning  :  beginning
# open.  :  open.
# make  :  make
# lesser  :  lesser
# seasons  :  season
# yielding  :  yielding
# fruitful  :  fruitful
# behold  :  behold
# one  :  one
# unto  :  unto
# made  :  made
# creature.  :  creature.
# good  :  good
# given.  :  given.
# seas  :  sea
# from.  :  from.
# lesser  :  lesser
# gathering  :  gathering
# wherein  :  wherein
# heaven.  :  heaven.
# seas  :  sea
# void  :  void
# years  :  year
# midst  :  midst
# without  :  without
# lights.  :  lights.
# moved  :  moved
# can't.  :  can't.

# %% [markdown]
# **Part of speech tagging of the filtered-words -**

# %%
nltk.pos_tag(filtered_words)
# Out:
# [('said', 'VBD'),
#  ("can't,", 'JJ'),
#  ('years', 'NNS'),
#  ('days', 'NNS'),
#  ('divided', 'VBD'),
#  ('fowl', 'JJ'),
#  ('likeness', 'JJ'),
#  ('second', 'JJ'),
#  ('subdue', 'JJ'),
#  ('hath', 'NN'),
#  ('blessed', 'VBN'),
#  ('image', 'NN'),
#  ('every', 'DT'),
#  ('gathering,', 'NN'),
#  ('called.', 'NN'),
#  ('heaven', 'RB'),
#  ('fish', 'JJ'),
#  ('that,', 'NN'),
#  ('fruitful', 'NN'),
#  ('called', 'VBN'),
#  ('grass', 'NN'),
#  ('brought', 'VBD'),
#  ('upon', 'IN'),
#  ('heaven,', 'NN'),
#  ('gathered', 'VBN'),
#  ('upon.', 'JJ'),
#  ('whose', 'WP$'),
#  ('signs', 'NNS'),
#  ('seas', 'VBP'),
#  ('let', 'VB'),
#  ('beast', 'JJ'),
#  ('a.', 'NN'),
#  ('is.', 'NN'),
#  ('greater,', 'NN'),
#  ('is.', 'NN'),
#  ('fowl', 'NN'),
#  ('air', 'NN'),
#  ('lights', 'NNS'),
#  ('them,', 'VBP'),
#  ('day', 'NN'),
#  ("you're.", 'VB'),
#  ('behold', 'JJ'),
#  ('god', 'NN'),
#  ('hath', 'NN'),
#  ('divide', 'RB'),
#  ('fruitful', 'JJ'),
#  ('every', 'DT'),
#  ('fruit', 'NN'),
#  ('set.', 'NN'),
#  ('behold', 'VBD'),
#  ('unto.', 'JJ'),
#  ('green', 'JJ'),
#  ('from.', 'NN'),
#  ('morning', 'NN'),
#  ('image,', 'NN'),
#  ('moving', 'VBG'),
#  ('gathering.', 'NN'),
#  ('set', 'VBN'),
#  ('firmament', 'JJ'),
#  ('forth', 'NN'),
#  ('creepeth', 'NNS'),
#  ('said,', 'VBP'),
#  ('above.', 'IN'),
#  ('moving', 'VBG'),
#  ('waters', 'NNS'),
#  ('let', 'VBP'),
#  ('green', 'JJ'),
#  ('female', 'JJ'),
#  ('one', 'CD'),
#  ('morning', 'NN'),
#  ('open', 'JJ'),
#  ('herb', 'NN'),
#  ('called', 'VBN'),
#  ('great,', 'NNS'),
#  ('make', 'VBP'),
#  ('seed', 'NN'),
#  ('fowl', 'NN'),
#  ('lights', 'NNS'),
#  ('second', 'JJ'),
#  ('life', 'NN'),
#  ('signs,', 'NN'),
#  ('made', 'VBD'),
#  ('wherein', 'JJ'),
#  ('dominion', 'NN'),
#  ('he,', 'NN'),
#  ('also', 'RB'),
#  ('said', 'VBD'),
#  ('kind', 'NN'),
#  ('beginning', 'VBG'),
#  ('fifth', 'JJ'),
#  ('one', 'CD'),
#  ('winged', 'VBN'),
#  ('upon', 'IN'),
#  ('created', 'VBN'),
#  ('fill', 'NN'),
#  ('open', 'JJ'),
#  ('face', 'NN'),
#  ('make', 'VBP'),
#  ('herb', 'NN'),
#  ('face.', 'NN'),
#  ('shall', 'MD'),
#  ('unto,', 'VB'),
#  ('very.', 'JJ'),
#  ('form', 'JJ'),
#  ('second', 'JJ'),
#  ('behold', 'NN'),
#  ('bring.', 'NN'),
#  ('behold', 'NN'),
#  ('rule', 'NN'),
#  ('fruit', 'NN'),
#  ('open', 'JJ'),
#  ('divided.', 'NN'),
#  ('deep', 'RB'),
#  ('good', 'JJ'),
#  ('upon,', 'JJ'),
#  ('herb', 'NN'),
#  ('form', 'NN'),
#  ('day', 'NN'),
#  ('place.', 'VBD'),
#  ('meat', 'NN'),
#  ('called', 'VBN'),
#  ('divide', 'VBP'),
#  ('us', 'PRP'),
#  ('fruit,', 'JJ'),
#  ('beginning', 'VBG'),
#  ('open.', 'JJ'),
#  ('make', 'VBP'),
#  ('lesser', 'JJR'),
#  ('seasons', 'NNS'),
#  ('yielding', 'VBG'),
#  ('fruitful', 'JJ'),
#  ('behold', 'JJ'),
#  ('one', 'CD'),
#  ('unto', 'NN'),
#  ('made', 'VBN'),
#  ('creature.', 'NN'),
#  ('good', 'JJ'),
#  ('given.', 'NN'),
#  ('seas', 'NNS'),
#  ('from.', 'VBP'),
#  ('lesser', 'JJR'),
#  ('gathering', 'NN'),
#  ('wherein', 'NN'),
#  ('heaven.', 'NN'),
#  ('seas', 'JJ'),
#  ('void', 'CD'),
#  ('years', 'NNS'),
#  ('midst', 'RB'),
#  ('without', 'IN'),
#  ('lights.', 'NN'),
#  ('moved', 'VBD'),
#  ("can't.", 'NN')]

# %% [markdown]
# **Part of Speech tagging for the list of all the words -**

# %%
nltk.pos_tag(list_word)
# Out:
# [('Said', 'NNP'),
#  ('ca', 'MD'),
#  ("n't", 'RB'),
#  (',', ','),
#  ('years', 'NNS'),
#  ('days', 'NNS'),
#  ('divided', 'VBD'),
#  ('fowl', 'JJ'),
#  ('likeness', 'JJ'),
#  ('second', 'JJ'),
#  ('subdue', 'JJ'),
#  ('hath', 'NN'),
#  ('blessed', 'VBN'),
#  ('image', 'NN'),
#  ('every', 'DT'),
#  ('gathering', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('called', 'VBD'),
#  ('.', '.'),
#  ('Heaven', 'NNP'),
#  ('Fish', 'NNP'),
#  ('that', 'IN'),
#  (',', ','),
#  ('fruitful', 'JJ'),
#  ('called', 'VBD'),
#  ('over', 'RP'),
#  ('grass', 'NN'),
#  ('brought', 'VBN'),
#  ('upon', 'IN'),
#  ('heaven', 'NN'),
#  (',', ','),
#  ('them', 'PRP'),
#  ('gathered', 'VBD'),
#  ('upon', 'NN'),
#  ('.', '.'),
#  ('That', 'IN'),
#  ('whose', 'WP$'),
#  ('signs', 'NNS'),
#  ('seas', 'VBP'),
#  ('for', 'IN'),
#  ('let', 'NN'),
#  ('beast', 'NN'),
#  ('a', 'DT'),
#  ('.', '.'),
#  ('Is', 'NN'),
#  ('.', '.'),
#  ('Greater', 'NNP'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('fowl', 'JJ'),
#  ('air', 'NN'),
#  ('lights', 'NNS'),
#  ('them', 'PRP'),
#  (',', ','),
#  ('day', 'NN'),
#  ('you', 'PRP'),
#  ("'re", 'VBP'),
#  ('.', '.'),
#  ('Behold', 'NNP'),
#  ('god', 'NN'),
#  ('be', 'VB'),
#  ('hath', 'JJ'),
#  ('divide', 'JJ'),
#  ('Fruitful', 'NNP'),
#  ('you', 'PRP'),
#  ("'re", 'VBP'),
#  ('every', 'DT'),
#  ('a', 'DT'),
#  ('have', 'VBP'),
#  ('over', 'RP'),
#  ('fruit', 'NN'),
#  ('set', 'VBN'),
#  ('.', '.'),
#  ('Behold', 'NNP'),
#  ('and', 'CC'),
#  ('our', 'PRP$'),
#  ('unto', 'NN'),
#  ('.', '.'),
#  ('Green', 'JJ'),
#  ('from', 'IN'),
#  ('.', '.'),
#  ('Morning', 'VBG'),
#  ('itself', 'PRP'),
#  ('image', 'NN'),
#  (',', ','),
#  ('have', 'VBP'),
#  ('moving', 'VBG'),
#  ('gathering', 'NN'),
#  ('.', '.'),
#  ('Set', 'NNP'),
#  ('firmament', 'JJ'),
#  ('forth', 'NN'),
#  ('creepeth', 'NN'),
#  ('said', 'VBD'),
#  (',', ','),
#  ('above', 'IN'),
#  ('.', '.'),
#  ('Moving', 'VBG'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('waters', 'NNS'),
#  ('let', 'VB'),
#  ('green', 'JJ'),
#  ('female', 'NN'),
#  ('i', 'NN'),
#  ('i', 'VBP'),
#  ('one', 'CD'),
#  ('morning', 'NN'),
#  ('i', 'NN'),
#  ('open', 'VBP'),
#  ('for', 'IN'),
#  ('herb', 'NN'),
#  ('called', 'VBN'),
#  ('great', 'JJ'),
#  (',', ','),
#  ('make', 'VB'),
#  ('itself', 'PRP'),
#  ('seed', 'NN'),
#  ('our', 'PRP$'),
#  ('fowl', 'JJ'),
#  ('lights', 'NNS'),
#  ('second', 'NN'),
#  ('to', 'TO'),
#  ('life', 'NN'),
#  ('signs', 'NNS'),
#  (',', ','),
#  ('made', 'VBN'),
#  ('have', 'VBP'),
#  ('wherein', 'JJ'),
#  ('dominion', 'NN'),
#  ('he', 'PRP'),
#  (',', ','),
#  ('also', 'RB'),
#  ('said', 'VBD'),
#  ('kind', 'NN'),
#  ('which', 'WDT'),
#  ('beginning', 'NN'),
#  ('had', 'VBD'),
#  ('fifth', 'JJ'),
#  ('one', 'CD'),
#  ('winged', 'VBN'),
#  ('upon', 'IN'),
#  ('so', 'RB'),
#  ('created', 'VBN'),
#  ('fill', 'NN'),
#  ('open', 'JJ'),
#  ('face', 'NN'),
#  ('make', 'VBP'),
#  ('herb', 'JJ'),
#  ('face', 'NN'),
#  ('.', '.'),
#  ('Be', 'VB'),
#  ('that', 'IN'),
#  ('shall', 'MD'),
#  ('their', 'PRP$'),
#  ('unto', 'NN'),
#  (',', ','),
#  ('very', 'RB'),
#  ('.', '.'),
#  ('Form', 'VB'),
#  ('second', 'JJ'),
#  ('were', 'VBD'),
#  ('behold', 'JJ'),
#  ('bring', 'NN'),
#  ('.', '.'),
#  ('Behold', 'NNP'),
#  ('rule', 'NN'),
#  ('fruit', 'NN'),
#  ('open', 'IN'),
#  ('he', 'PRP'),
#  ('divided', 'VBD'),
#  ('.', '.'),
#  ('Deep', 'VB'),
#  ('their', 'PRP$'),
#  ('good', 'JJ'),
#  ('upon', 'NN'),
#  (',', ','),
#  ('herb', 'JJ'),
#  ('form', 'NN'),
#  ('day', 'NN'),
#  ('above', 'IN'),
#  ('place', 'NN'),
#  ('.', '.'),
#  ('Meat', 'NN'),
#  ('called', 'VBN'),
#  ('divide', 'NN'),
#  ('is', 'VBZ'),
#  ('us', 'PRP'),
#  ('be', 'VB'),
#  ('fruit', 'VBN'),
#  (',', ','),
#  ('beginning', 'VBG'),
#  ('open', 'JJ'),
#  ('.', '.'),
#  ('Make', 'NNP'),
#  ('lesser', 'JJR'),
#  ('which', 'WDT'),
#  ('you', 'PRP'),
#  ('seasons', 'NNS'),
#  ('Be', 'VB'),
#  ('yielding', 'VBG'),
#  ('fruitful', 'JJ'),
#  ('behold', 'JJ'),
#  ('one', 'CD'),
#  ('wo', 'MD'),
#  ("n't", 'RB'),
#  ('unto', 'VB'),
#  ('made', 'VBN'),
#  ('creature', 'NN'),
#  ('.', '.'),
#  ('Good', 'JJ'),
#  ('were', 'VBD'),
#  ('given', 'VBN'),
#  ('.', '.'),
#  ('Which', 'JJ'),
#  ('seas', 'NN'),
#  ('from', 'IN'),
#  ('.', '.'),
#  ('Have', 'VBP'),
#  ('so', 'RB'),
#  ('lesser', 'JJR'),
#  ('which', 'WDT'),
#  ('and', 'CC'),
#  ('gathering', 'VBG'),
#  ('wherein', 'JJ'),
#  ('heaven', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('seas', 'JJ'),
#  ('void', 'NN'),
#  ('years', 'NNS'),
#  ('Midst', 'NNP'),
#  ('without', 'IN'),
#  ('lights', 'NNS'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('moved', 'VBN'),
#  ('ca', 'MD'),
#  ("n't", 'RB'),
#  ('.', '.')]
